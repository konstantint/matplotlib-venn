# %% [markdown]
# ## Venn2 :: Visual review of special cases

# %%
from matplotlib_venn import venn2

# %%
venn2((1, 1, 1));

# %%
venn2((0, 0, 0));
# Out:
# matplotlib_venn\_venn2.py:46: UserWarning: Both circles have zero area
#   warnings.warn("Both circles have zero area")

# %%
venn2((0, 0, 1));

# %%
venn2((0, 1, 0));
# Out:
# matplotlib_venn\_math.py:134: RuntimeWarning: divide by zero encountered in double_scalars
#   cos_gamma = (d_ab**2 + r_a**2 - r_b**2) / 2.0 / d_ab / r_a

# %%
venn2((0, 1, 1));

# %%
venn2((1, 0, 0));

# %%
venn2((1, 0, 1));

# %%
venn2((1, 1, 0));
